# %%
# import modules
import os
import pandas as pd

# %%
# reload extension
# %reload_ext jupyter-rdfify

# %%
# set directory, filename, and path
dir = os.getcwd()
filename = 'gofood_dataset.csv'
filepath = os.path.join(dir, filename)

# %%
# read data and display data
dataframe = pd.read_csv('gofood_dataset.csv')
dataframe
# Out:
#            merchant_name merchant_area           category            display  \
# 0      330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti          Signature
# 1      330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti          Signature
# 2      330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti          Signature
# 3      330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti          Signature
# 4      330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti          Signature
# ...                  ...           ...                ...                ...
# 45190   Zeger!, Sidoarjo      surabaya       Minuman/Kopi  1L ZEGER BANGET !
# 45191   Zeger!, Sidoarjo      surabaya       Minuman/Kopi  1L ZEGER BANGET !
# 45192   Zeger!, Sidoarjo      surabaya       Minuman/Kopi  1L ZEGER BANGET !
# 45193   Zeger!, Sidoarjo      surabaya       Minuman/Kopi  1L ZEGER BANGET !
# 45194   Zeger!, Sidoarjo      surabaya       Minuman/Kopi  1L ZEGER BANGET !
#
# ...

# %%
# use 4 column of the data and select 5 rows
data = dataframe[['merchant_name', 'merchant_area', 'product', 'price']].head(5)
data
# Out:
#        merchant_name merchant_area                                product  \
# 0  330 Kopi, Ciledug       jakarta  Hot Almara Kopi (kopi Susu Gula Aren)
# 1  330 Kopi, Ciledug       jakarta  Ice Almara Kopi (kopi Susu Gula Aren)
# 2  330 Kopi, Ciledug       jakarta                            Hot Millsis
# 3  330 Kopi, Ciledug       jakarta                            Ice Millsis
# 4  330 Kopi, Ciledug       jakarta                            Hot Millbro
#
#      price
# 0  20000.0
# 1  22000.0
# 2  20000.0
# 3  20000.0
# 4  22000.0

# %%
# %%rdf turtle -l gofood
#
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix ex: <http://example.org/>.
#
# ex:merchant a rdfs:Class.
# ex:area a rdfs:Class.
# ex:product a rdfs:Class.
#
# ex:berlokasi a rdf:Property.
# ex:berlokasi rdfs:domain ex:merchant.
# ex:berlokasi rdfs:range ex:area.
#
# ex:menjual a rdf:Property.
# ex:menjual rdfs:domain ex:merchant.
# ex:menjual rdfs:range ex:product.
#
# ex:berharga a rdf:Property.
# ex:berharga rdfs:domain ex:product.
# ex:berharga rdfs:range xsd:integer.
#
# ex:KopiCiledug a ex:merchant.
# ex:jakarta a ex:area.
# ex:KopiCiledug ex:berlokasi ex:jakarta.
#
# ex:HotAlmaraKopi a ex:product.
# ex:HotAlmaraKopi ex:berharga "20000"^^xsd:integer.
#
# ex:IceAlmaraKopi a ex:product.
# ex:IceAlmaraKopi ex:berharga "22000"^^xsd:integer.
#
# ex:KopiCiledug ex:menjual ex:HotAlmaraKopi.
# ex:KopiCiledug ex:menjual ex:IceAlmaraKopi.
