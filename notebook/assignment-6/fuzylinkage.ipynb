# %%
# pip install fuzzymatcher

# %%
import pandas as pd
from pathlib import Path
import fuzzymatcher

# %%
hospital_accounts = pd.read_csv('hospital_account_info.csv')
hospital_reimbursement = pd.read_csv('hospital_reimbursement.csv')

# %%
left_on = ["Facility Name", "Address", "City", "State"]

right_on = [
    "Provider Name", "Provider Street Address", "Provider City",
    "Provider State"
]

# %%
matched_results = fuzzymatcher.fuzzy_left_join(hospital_accounts,
                                            hospital_reimbursement,
                                            left_on,
                                            right_on,
                                            left_id_col='Account_Num',
                                            right_id_col='Provider_Num')

# %%
cols = [
    "best_match_score", "Facility Name", "Provider Name", "Address", "Provider Street Address",
    "Provider City", "City", "Provider State", "State"
]

matched_results[cols].sort_values(by=['best_match_score'], ascending=False).head(5)
# Out:
#         best_match_score                                      Facility Name  \
# 78185           3.090931    RARITAN BAY MEDICAL CENTER PERTH AMBOY DIVISION
# 534294          2.799072            ROBERT WOOD JOHNSON UNIVERSITY HOSPITAL
# 78774           2.785132  AVERA MCKENNAN HOSPITAL & UNIVERSITY HEALTH CE...
# 243236          2.778860  JOHN T MATHER MEMORIAL HOSPITAL  OF PORT JEFFE...
# 448678          2.721425               MAYO CLINIC HEALTH SYSTEM - RED WING
#
#                                             Provider Name  \
# 78185     RARITAN BAY MEDICAL CENTER PERTH AMBOY DIVISION
# 534294            ROBERT WOOD JOHNSON UNIVERSITY HOSPITAL
# 78774   AVERA MCKENNAN HOSPITAL & UNIVERSITY HEALTH CE...
# 243236  JOHN T MATHER MEMORIAL HOSPITAL  OF PORT JEFFE...
# 448678              MAYO CLINIC HEALTH SYSTEM IN RED WING
#
#                                        Address  \
# 78185                    530 NEW BRUNSWICK AVE
# 534294           ONE ROBERT WOOD JOHNSON PLACE
# 78774   1325 S CLIFF AVE  POST OFFICE BOX 5045
# 243236                   75 NORTH COUNTRY ROAD
# 448678         701 HEWITT BOULEVARD, PO BOX 95
#
#                        Provider Street Address   Provider City  \
# 78185                    530 NEW BRUNSWICK AVE     PERTH AMBOY
# 534294           ONE ROBERT WOOD JOHNSON PLACE   NEW BRUNSWICK
# 78774   1325 S CLIFF AVE  POST OFFICE BOX 5045     SIOUX FALLS
# 243236                   75 NORTH COUNTRY ROAD  PORT JEFFERSON
# 448678         701 HEWITT BOULEVARD, PO BOX 95        RED WING
#
#                   City Provider State State
# 78185      PERTH AMBOY             NJ    NJ
# 534294   NEW BRUNSWICK             NJ    NJ
# 78774      SIOUX FALLS             SD    SD
# 243236  PORT JEFFERSON             NY    NY
# 448678        RED WING             MN    MN

# %%
matched_results[cols].sort_values(by=['best_match_score'], ascending=True).head(5)
# Out:
#         best_match_score                                      Facility Name  \
# 427588         -2.268231                      CENTRO MEDICO WILMA N VAZQUEZ
# 83354          -2.124071  DOCTOR CENTER HOSPITAL SAN FERNANDO DE LA CARO...
# 42712          -2.106746     HOSPITAL ONCOLOGICO DR ISAAC GONZALEZ MARTINEZ
# 451649         -2.050888           CENTRO DE SALUD CONDUCTUAL MENONITA-CIMA
# 477713         -1.996508             ADMIN DE SERVICIOS MEDICOS  PUERTO RIC
#
#                            Provider Name  \
# 427588       BAPTIST MEDICAL CENTER EAST
# 83354   OVERLAKE HOSPITAL MEDICAL CENTER
# 42712             SCRIPPS MERCY HOSPITAL
# 451649   MILFORD REGIONAL MEDICAL CENTER
# 477713              MAINE MEDICAL CENTER
#
#                                                   Address  \
# 427588      CARR. 2 KM 39.5    ROAD NUMBER 2 BO ALGARROBO
# 83354   EDIF JESUS T PINEIRO AVE FERNANDEZ JUNCOS BO P...
# 42712   BO. MONACILLOS CARR 22 CENTRO MEDICO DE PUERTO...
# 451649  CARR ESTATAL 14 INTERIOR SARGENTO GERARDO SANT...
# 477713                           BO MONACILLO CARR NUM 22
#
#        Provider Street Address Provider City       City Provider State State
# 427588         400 TAYLOR ROAD    MONTGOMERY  VEGA BAJA             AL    PR
# 83354        1035-116TH AVE NE      BELLEVUE   CAROLINA             WA    PR
# 42712             4077 5TH AVE     SAN DIEGO   SAN JUAN             CA    PR
# 451649      14 PROSPECT STREET       MILFORD   AIBONITO             MA    PR
# 477713          22 BRAMHALL ST      PORTLAND   SAN JUAN             ME    PR

# %%
matched_results[cols].query("best_match_score <= .80").sort_values(
    by=['best_match_score'], ascending=False).head(20)
# Out:
#         best_match_score                          Facility Name  \
# 519859          0.792471               METHODIST HOSPITAL SOUTH
# 418133          0.791668          ADVENTIST HEALTH UKIAH VALLEY
# 304009          0.787163                         MADISON HEALTH
# 389271          0.776632              PENN HIGHLANDS CLEARFIELD
# 494529          0.775573          MEMORIAL HOSPITAL AT GULFPORT
# 307813          0.774358                      BLESSING HOSPITAL
# 128549          0.764895   ST LUKE'S HOSPITAL - ANDERSON CAMPUS
# 428870          0.756481         CHILDREN'S HOSPITAL AT MISSION
# 490189          0.755511          ADVENTHEALTH HEART OF FLORIDA
# 212703          0.753739                  SOVAH HEALTH DANVILLE
# 429961          0.753465                          PHELPS HEALTH
# 308918          0.752712                  SAINT MARY'S HOSPITAL
# 466087          0.752218                     ST PETERS HOSPITAL
# 570390          0.752179        FRANCISCAN HEALTH MICHIGAN CITY
# 180067          0.745897        HCA HOUSTON HEALTHCARE KINGWOOD
# 147454          0.744798                ADVENTIST HEALTH SONORA
# 552047          0.739983                ADVENTHEALTH MANCHESTER
# 405375          0.739409                              UPMC KANE
# 400625          0.738336  MARSHFIELD MEDICAL CENTER - RICE LAKE
# 478648          0.736923                     TRINITY BETTENDORF
#
#                                    Provider Name  \
# 519859       SOUTH TEXAS REGIONAL MEDICAL CENTER
# 418133               UKIAH VALLEY MEDICAL CENTER
# 304009               MADISON COUNTY HOSPITAL INC
# 389271                       CLEARFIELD HOSPITAL
# 494529             MEMORIAL HOSPITAL AT GULFPORT
# 307813                         BLESSING HOSPITAL
# 128549      ST LUKE'S HOSPITAL - ANDERSON CAMPUS
# 428870      MISSION HOSPITAL REGIONAL MED CENTER
# 490189  HEART OF FLORIDA REGIONAL MEDICAL CENTER
# 212703          DANVILLE REGIONAL MEDICAL CENTER
# 429961     PHELPS COUNTY REGIONAL MEDICAL CENTER
# 308918                      SAINT MARYS HOSPITAL
# 466087                       ST PETER'S HOSPITAL
# 570390           FRANCISCAN HEALTH MICHIGAN CITY
# 180067                   KINGWOOD MEDICAL CENTER
# 147454            SONORA REGIONAL MEDICAL CENTER
# 552047                         MEMORIAL HOSPITAL
# 405375                   KANE COMMUNITY HOSPITAL
# 400625                   LAKEVIEW MEDICAL CENTER
# 478648                UNITY POINT HEALTH TRINITY
#
#                                    Address    Provider Street Address  \
# 519859                    1905 HWY 97 EAST           1905 HWY 97 EAST
# 418133                  275 HOSPITAL DRIVE         275 HOSPITAL DRIVE
# 304009               210 NORTH MAIN STREET      210 NORTH MAIN STREET
# 389271                    809 TURNPIKE AVE           809 TURNPIKE AVE
# 494529                    4500 13TH STREET  4500 13TH ST-P O BOX 1810
# 307813             BROADWAY ST & N 11TH ST    BROADWAY AT 11TH STREET
# 128549                 1872 ST LUKE'S BLVD      1872 RIVERSIDE CIRCLE
# 428870  27700 MEDICAL CENTER RD, 5TH FLOOR    27700 MEDICAL CENTER RD
# 490189                        40100 HWY 27          40100 US HWY 27 N
# 212703               142 SOUTH MAIN STREET      142 SOUTH MAIN STREET
# 429961                      1000 W 10TH ST             1000 W 10TH ST
# 308918                   56 FRANKLIN STEET             56 FRANKLIN ST
# 466087                       2475 BROADWAY              2475 BROADWAY
# 570390                 3500 FRANCISCAN WAY             301 W HOMER ST
# 180067                     22999 US HWY 59            22999 US HWY 59
# 147454                  1000 GREENLEY ROAD         1000 GREENLEY ROAD
# 552047             210 MARIE LANGDON DRIVE    210 MARIE LANGDON DRIVE
# 405375                        4372 ROUTE 6               4372 ROUTE 6
# 400625              1700 WEST STOUT STREET     1700 WEST STOUT STREET
# 478648               4500 UTICA RIDGE ROAD      4500 UTICA RIDGE ROAD
#
#         Provider City           City Provider State State
# 519859     JOURDANTON     JOURDANTON             TX    TX
# 418133          UKIAH          UKIAH             CA    CA
# 304009         LONDON         LONDON             OH    OH
# 389271     CLEARFIELD     CLEARFIELD             PA    PA
# 494529       GULFPORT       GULFPORT             MS    MS
# 307813         QUINCY         QUINCY             IL    IL
# 128549         EASTON         EASTON             PA    PA
# 428870  MISSION VIEJO  MISSION VIEJO             CA    CA
# 490189      DAVENPORT      DAVENPORT             FL    FL
# 212703       DANVILLE       DANVILLE             VA    VA
# 429961          ROLLA          ROLLA             MO    MO
# 308918      WATERBURY      WATERBURY             CT    CT
# 466087         HELENA         HELENA             MT    MT
# 570390  MICHIGAN CITY  MICHIGAN CITY             IN    IN
# 180067       KINGWOOD       KINGWOOD             TX    TX
# 147454         SONORA         SONORA             CA    CA
# 552047     MANCHESTER     MANCHESTER             KY    KY
# 405375           KANE           KANE             PA    PA
# 400625      RICE LAKE      RICE LAKE             WI    WI
# 478648     BETTENDORF     BETTENDORF             IA    IA
